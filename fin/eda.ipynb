# %%
import quandl

# %%
quandl.ApiConfig.api_key = "oRsYTtUk9sxAsuPmo9Zy"

# %%
mydata = quandl.get('NSE/RELIANCE', start_date='2019-01-01', end_date='2019-01-20')

# %%
mydata
# Out:
#                Open     High     Low     Last    Close  Total Trade Quantity  \
# Date
# 2019-01-01  1125.25  1127.30  1110.1  1120.50  1121.00             4455850.0
# 2019-01-02  1114.50  1127.00  1101.0  1104.35  1106.40             7144970.0
# 2019-01-03  1107.50  1114.60  1090.1  1090.30  1092.75             7446457.0
# 2019-01-04  1097.40  1104.45  1081.1  1099.60  1098.65             8465141.0
#
#             Turnover (Lacs)
# Date
# 2019-01-01         49861.29
# 2019-01-02         79553.42
# 2019-01-03         82012.92
# 2019-01-04         92529.47

# %%
#https://nsetools.readthedocs.io/en/latest/usage.html
from nsetools import Nse

# %%
nse = Nse()

# %%
q = nse.get_quote('infy')

# %%
print(q)
# Out:
# {'sellPrice1': None, 'deliveryQuantity': 9286884.0, 'exDate': '24-JAN-19', 'css_status_desc': 'Listed', 'symbol': 'INFY', 'pChange': 1.64, 'change': 11.65, 'sellPrice2': None, 'buyQuantity5': None, 'pricebandlower': 637.55, 'buyPrice3': None, 'securityVar': 4.31, 'totalSellQuantity': None, 'extremeLossMargin': 5.0, 'sellQuantity3': None, 'high52': 772.25, 'sellQuantity4': None, 'marketType': 'N', 'indexVar': None, 'companyName': 'Infosys Limited', 'ndStartDate': None, 'buyPrice4': None, 'sellQuantity2': None, 'priceBand': 'No Band', 'deliveryToTradedQuantity': 63.44, 'cm_ffm': 273098.33, 'buyPrice2': None, 'bcStartDate': None, 'low52': 551.0, 'cm_adj_high_dt': '08-FEB-19', 'recordDate': '25-JAN-19', 'series': 'EQ', 'buyPrice5': None, 'sellQuantity1': None, 'quantityTraded': 14638664.0, 'sellPrice5': None, 'buyQuantity1': 480.0, 'buyQuantity2': None, 'dayHigh': 723.75, 'averagePrice': 717.56, 'lastPrice': 720.0, 'dayLow': 709.6, 'isExDateFlag': False, 'isinCode': 'INE009A01021', 'appl
# ...

# %%
print(nse.get_index_list())
# Out:
# ['NIFTY 50 Pre Open', 'NIFTY 50', 'NIFTY NEXT 50', 'NIFTY100 LIQ 15', 'NIFTY BANK', 'INDIA VIX', 'NIFTY 100', 'NIFTY 500', 'NIFTY MIDCAP 100', 'NIFTY MIDCAP 50', 'NIFTY INFRA', 'NIFTY REALTY', 'NIFTY ENERGY', 'NIFTY FMCG', 'NIFTY MNC', 'NIFTY PHARMA', 'NIFTY PSE', 'NIFTY PSU BANK', 'NIFTY SERV SECTOR', 'NIFTY IT', 'NIFTY SMLCAP 100', 'NIFTY 200', 'NIFTY AUTO', 'NIFTY MEDIA', 'NIFTY METAL', 'NIFTY DIV OPPS 50', 'NIFTY COMMODITIES', 'NIFTY CONSUMPTION', 'NIFTY CPSE', 'NIFTY FIN SERVICE', 'NIFTY GROWSECT 15', 'NIFTY50 VALUE 20', 'NIFTY50 TR 2X LEV', 'NIFTY50 PR 2X LEV', 'NIFTY50 TR 1X INV', 'NIFTY50 PR 1X INV', 'NIFTY ALPHA 50', 'NIFTY50 EQL WGT', 'NIFTY100 EQL WGT', 'NIFTY100 LOWVOL30', 'NIFTY MID LIQ 15', 'NIFTY PVT BANK', 'NIFTY100 QUALTY30', 'NIFTY GS 8 13YR', 'NIFTY GS 10YR', 'NIFTY GS 10YR CLN', 'NIFTY GS 4 8YR', 'NIFTY GS 11 15YR', 'NIFTY GS 15YRPLUS', 'NIFTY GS COMPSITE', 'NIFTY MIDCAP 150', 'NIFTY SMLCAP 50', 'NIFTY SMLCAP 250', 'NIFTY MIDSML 400', 'NIFTY200 QUALTY30']

# %%
print(nse.get_index_quote("NIFTY 50"))
# Out:
# {'name': 'NIFTY 50', 'lastPrice': 11426.85, 'imgFileName': 'NIFTY_50_open.png', 'pChange': 0.74, 'change': 83.6}

# %%
all_stock_codes = nse.get_stock_codes()

# %%
from nsepy import get_history

# %%
from datetime import date
from nsepy import get_history
sbin = get_history(symbol='SBIN',
                   start=date(2019,3,1),
                   end=date(2019,3,15))

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-03-01   SBIN     EQ      269.05  270.55  274.60  270.10  272.85  272.95
# 2019-03-05   SBIN     EQ      272.95  271.70  277.85  271.20  275.95  276.45
# 2019-03-06   SBIN     EQ      276.45  277.30  282.55  276.45  278.10  278.10
# 2019-03-07   SBIN     EQ      278.10  279.45  282.50  277.65  281.95  281.75
# 2019-03-08   SBIN     EQ      281.75  281.85  284.25  279.60  281.50  281.20
# 2019-03-11   SBIN     EQ      281.20  285.30  289.00  283.50  286.95  287.35
# 2019-03-12   SBIN     EQ      287.35  289.20  289.90  285.75  287.30  286.90
# 2019-03-13   SBIN     EQ      286.90  288.10  294.40  284.70  293.85  293.15
# 2019-03-14   SBIN     EQ      293.15  294.50  294.70  290.75  292.10  291.90
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-03-01  272.87  20024726  5.464233e+14  103387             9418388
# ...
